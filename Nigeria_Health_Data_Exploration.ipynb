# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadnasirahmad1992/ahmad-ai-health-journey/blob/main/Nigeria_Health_Data_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv ("access-to-health-care_subnational_nga.csv")
print("Shape (rows, columns):", df.shape)
# Out:
# Shape (rows, columns): (10000, 30)

# %%
print(df.columns.tolist())
# Out:
# ['ISO3', 'Location', 'DataId', 'Indicator', 'Value', 'Precision', 'DHS_CountryCode', 'CountryName', 'SurveyYear', 'SurveyId', 'IndicatorId', 'IndicatorOrder', 'IndicatorType', 'CharacteristicId', 'CharacteristicOrder', 'CharacteristicCategory', 'CharacteristicLabel', 'ByVariableId', 'ByVariableLabel', 'IsTotal', 'IsPreferred', 'SDRID', 'RegionId', 'SurveyYearLabel', 'SurveyType', 'DenominatorWeighted', 'DenominatorUnweighted', 'CILow', 'CIHigh', 'LevelRank']

# %%
df.head()
# Out:
#   ISO3          Location   DataId                        Indicator  Value  \
# 0  NGA  Northeast - 1990  7265726  Antenatal care provider: Doctor   26.7
# 1  NGA  Northeast - 1990  7823224  Antenatal care provider: Doctor   25.4
# 2  NGA  Northeast - 1990  2839267  Antenatal care provider: Doctor   28.6
# 3  NGA  Northwest - 1990  4549176  Antenatal care provider: Doctor   29.0
# 4  NGA  Northwest - 1990  6037839  Antenatal care provider: Doctor   31.3
#
#    Precision DHS_CountryCode CountryName  SurveyYear   SurveyId  ...  \
# 0          1              NG     Nigeria        1990  NG1990DHS  ...
# 1          1              NG     Nigeria        1990  NG1990DHS  ...
# 2          1              NG     Nigeria        1990  NG1990DHS  ...
# 3          1              NG     Nigeria        1990  NG1990DHS  ...
# 4          1              NG     Nigeria        1990  NG1990DHS  ...
#
#   IsPreferred       SDRID         RegionId  SurveyYearLabel  SurveyType  \
# ...

# %%
df.describe()
# Out:
#              DataId         Value     Precision    SurveyYear  IndicatorOrder  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000    1.000000e+04
# mean   4.083309e+06    194.656920      0.785400   2010.183700    8.647839e+07
# std    2.254838e+06    643.358843      0.410565      5.970923    4.733846e+06
# min    1.440000e+02      0.000000      0.000000   1990.000000    8.336301e+07
# 25%    2.271267e+06      2.400000      1.000000   2010.000000    8.336314e+07
# 50%    4.155414e+06     28.000000      1.000000   2013.000000    8.360607e+07
# 75%    5.979060e+06     92.000000      1.000000   2013.000000    9.396603e+07
# max    7.942491e+06  11775.000000      1.000000   2015.000000    9.409617e+07
#
#        CharacteristicId  CharacteristicOrder  ByVariableId  IsTotal  \
# count      10000.000000         1.000000e+04  10000.000000  10000.0
# mean      433025.360500         1.433034e+06  12866.784400      0.0
# ...

# %%
print("Distinct indicators:",
df['Indicator'].nunique())
print(df['Indicator'].unique()[:20])
# Out:
# Distinct indicators: 78
# ['Antenatal care provider: Doctor'
#  'Antenatal care provider: Nurse/midwife'
#  'Antenatal care provider: Auxiliary nurse/midwife'
#  'Antenatal care provider: Community health worker'
#  'Antenatal care provider: Other health worker'
#  'Antenatal care provider: Traditional birth attendant'
#  'Antenatal care provider: Other' 'Antenatal care provider: Missing '
#  'No antenatal care' 'Antenatal care: Total'
#  'Antenatal care from a skilled provider'
#  'Number of women with a live birth (or stillbirth) in the last two (or three/five) years'
#  'Number of women with a live birth (or stillbirth) in the last two (or three/five) years (unweighted)'
#  'Place of delivery: Public sector' 'Place of delivery: Private sector'
#  'Place of delivery: At home' 'Place of delivery: Other'
#  "Place of delivery: don't know or missing" 'Place of delivery: Total'
#  'Place of delivery: Health facility']

# %%
print("Distinct locations:",
df['Location'].nunique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5711/3382491232.py in <cell line: 0>()
#       1 print("Distinct locations:",
# ----> 2 df['Location'].nunique())
#
# NameError: name 'df' is not defined
